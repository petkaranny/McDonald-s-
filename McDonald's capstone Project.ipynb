# %% [markdown]
# # <font color = darkpink > PROJECT STATEMENT </font>

# %% [markdown]
# <b>McDonald's is one of the largest and most recognizable fast-food chains globally, offering a wide variety of menu items. With growing consumer awareness about health and nutrition, there is an increasing demand for transparency and insights into the nutritional content of fast-food offerings. Understanding the nutritional profile of McDonald's menu items can help consumers make informed dietary choices and aid the company in improving its menu for better health outcomes.

# %% [markdown]
# # <font color = darkpink> DATA </font>

# %% [markdown]
# <b> Category </b>: Category of menu item <br>
#
# <b>Item </b>: Name of the menu <br>
#
# <b>Serving Size </b> : Serving size of the menu item in ounce and grams <br>
#
# <b>Calories</b> : Calories count of the menu item.<br>
#
# <b>Calories from Fat</b> : Calories count from fat of the menu item <br>
#
# <b>Total Fat</b> : Total fat of the menu item <br>
#
# <b>Toalt Fat(% Daily value)</b> : Daily percentage value of total fat <br>
#
# <b>Saturated Fat</b> : Total saturated fat of the menu item <br>
#
# <b>Trans Fat</b> : Total trans fat of the menu item <br>
#
# <b>Cholesterol</b> : Total cholestrol value of the menu item <br>
#
# <b>Cholesterol (% Daily Value)</b> : Daily percentage value of Cholestrol <br>
#
# <b>Sodium</b> : Total sodium count in the menu item <br>
#
# <b>Sodium (% Daily value)</b> : Daily percentage value of the sodium in the menu item <br>
#
# <b>Carbohydrate</b> : Total carbohydrates count in the menu <br>
#
# <b>Carbohydrate (% Daily values)</b> : Daily percentage values of a carbohyderate <br>
#
# <b>Dietary Fiber</b> : Total dietray fiber in the menu item <br>
#
# <b>Protien</b> : Total Protine in the menu item <br>
#
# <b>Vitamin A (% Daily Values)</b> : Daily percentage values of vitamin A<br>
#
# <b>Vitamin C (% Daily Values)</b> : Daily Percentage Value of vitamin C<br>
#
# <b>Calcium (% Daily value)</b> : Daily Percentage Value of Calcium <br>
#
# <b>Iron ( % DAily Value)</b> : Daily Percentage value of Iron <br>

# %% [markdown]
# # <font color = darkpink> CONTENT </font>

# %% [markdown]
# 1. Import Libraries
# 2. Data Preparation
# 3. Understanding the Data
# 4. Exploratory Data Analysis
# 5. Outlier Treatment
# 6. Missing Value Treatment

# %% [markdown]
# # <font color= darkpink> DATA CLEANING </font>

# %% [markdown]
# # <font color= darkpink> 1. IMPORT LIBRARIES </font>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %% [markdown]
# # <font color = darkpink> 2. DATA PREPARATION </font>

# %%
df=pd.read_csv(r"C:\Users\annie\Downloads\Nutrical Dataset.1.csv")
df.sample()
# Out:
#           Category          Item  Serving Size  Calories  Calories from Fat  \
# 83  Chicken & Fish  Filet-O-Fish  5 oz (142 g)       390                170
#
#     Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 83       19.0                         29            4.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 83                             19        0.0  ...             39
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 83                             13              2
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 83                              7       5       15                          2
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 83                          0                       15                    10
#
# [1 rows x 24 columns]

# %% [markdown]
# # <font color= darkpink>2.1 UNDERSTANDING THE DATA</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
len (df)
# Out:
# 260

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 24

# %% [markdown]
# # <font color= darkpink>2.2 EXPLORATORY DATA ANALYSIS</font>

# %%
plt.figure(figsize=(15,5))
sns.histplot(x= 'Calories', data=df, color= 'lightsalmon', bins=20)
plt.show()

# %% [markdown]
# > <b> Most menu items have a calories count within the range (188 to 282)

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='Sugars', data= df, color='#ffff80', bins=16)
plt.show()

# %% [markdown]
# > <b>Most menu items have a sugar level within the range (0 to 8)

# %%
max_fat=df.sort_values('Total Fat').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y= 'Item', x= 'Total Fat', data = max_fat, hue= 'Item')
plt.show()

# %% [markdown]
# ><b> Item named Chicken McNuggets (40 piece) has highest Fat value

# %%
max_protein=df.sort_values('Protein').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y= 'Item', x= 'Total Fat', data=max_protein, hue= 'Item')
plt.show()

# %% [markdown]
# ><b>Item name Chicken McNuggets (40 piece) has highest protein value

# %%
max_carb=df.sort_values('Carbohydrates').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y= 'Item', x= 'Total Fat', data=max_carb, hue= 'Item')
plt.show()

# %% [markdown]
# ><b>Item name Chicken McNuggets (40 piece) has highest Carbohydrates value

# %% [markdown]
# ><b> Identify trends and patterns in the dataset.

# %% [markdown]
# plt.figure(figsize=(8,3))
# sns.barplot(y='Category', x= 'Vitamin A (% Daily Value)', data=df,hue='Category')
# plt.show()

# %% [markdown]
# ><b>Salads are rich in Vitamin A where as Beverage are poor source of Item

# %%
plt.figure(figsize = (8,3))
sns.barplot(y='Category',x='Iron (% Daily Value)',data=df,hue='Category')
plt.show()

# %% [markdown]
# ><b> Beef and Porks are rich in Iron whereas Beverages are Poor source of Item

# %%
plt.figure(figsize=(8,3))
sns.barplot(y= 'Category', x='Protein', data=df, hue='Category')
plt.show()

# %% [markdown]
# ><b> Chicken and Fish are rich in Protein whereas Beverages are good fow low protein diet

# %%
plt.figure(figsize=(10,3))
sns.boxplot(y='Cholesterol', hue='Category',data=df)
plt.legend(ncols=df['Category'].nunique()/3)
plt.show()

# %% [markdown]
#  # <font color = darpink> 2.4 OUTLIER TREATMENT </font>

# %%
col=df.select_dtypes(exclude='object').columns
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[col] < (Q1 - 1.5*IQR))| (df[col] > (Q3 + 1.5*IQR))).any(axis=1)]

# %%
# Total number of records after removing the outliers
len(df)
# Out:
# 113

# %% [markdown]
# # <font color = darkpink> 2.4 MISSING VALUE TREATMENT </font>

# %%
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# ><b>In this dataset there are no missing values so wer are good to proceed with any further analysys

# %% [markdown]
# # <font color = darkpink> Summary Of Recommendations To Improve McDonalds Nutritional Profile</font>

# %% [markdown]
# <b>1.Reduce calorie-dense Ingredients</b> : Offer smaller protions and low-calorie with lener meats and  whole-grain bun.<br>
#
# <b>2.Increse nutrient- dense option</b> : Add more salads, fruits, and vegetable-based dishes and offer healthy sides like apple slices and yogurt.<br>
#
# <b>3.Enhance transparency and education</b> : Provide clear nutritional information and run health education campaigns.<br>
#
# <b>4.Reduce sodium and sugar</b> : Lower sodium in high-sodium item and cut added sugars in drinks and desserts.<br>
#
# <b>5.Itroduce plant-based options</b> : Expand vegetarian and vegan choices and use plant-based meat alternatives.<br>
#
# <b>6.Focus on healthy cooking methods</b> : Promote grilling over frying and use healthier cooking oils.<br>
#
# <b>7.Collaborate with nutrition experts </b>: Work with nutritionists to improve recipes and regularly update the menu based on health trends.<br>

# %% [markdown]
# ><b> By implementing the changes, McDonald's can offer healthier menu cater to consumer demand for better nutrition while maintaining taste and convenience.
